# %% [markdown]
# # Fraud model training with MLflow (Phase 3)
#
# This notebook demonstrates how to:
#
# - Generate a small synthetic dataset (reusing the Phase 2 generator)
# - Build a fraud training DataFrame
# - Train an XGBoost model with Optuna tuning
# - Log metrics, parameters, model, and SHAP artifacts to MLflow

# %%
from pathlib import Path

import mlflow

from scripts.seed_data import generate_synthetic_data
from common.model_utils import build_fraud_training_dataframe, train_fraud_model
# Out:
# d:\ai_ws\projects\ibook_ai_ops\.venv\Lib\site-packages\mlflow\utils\requirements_utils.py:20: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources  # noqa: TID251

# %%
# Generate a modest dataset so the notebook runs quickly.

project_root = Path.cwd()
print(f"Project root: {project_root}")

event_metrics, user_metrics = generate_synthetic_data(
    n_events=50,
    n_users=500,
    n_transactions=5000,
    seed=42,
)

user_metrics.head()
# Out:
# Project root: d:\ai_ws\projects\ibook_ai_ops\notebooks
#    user_id                  event_timestamp  lifetime_purchases  \
# 0        1 2025-12-27 08:27:54.080211+00:00                  26
# 1        2 2025-02-21 08:27:54.080211+00:00                  23
# 2        3 2024-07-08 08:27:54.080211+00:00                  31
# 3        4 2023-05-06 08:27:54.080211+00:00                  36
# 4        5 2023-11-14 08:27:54.080211+00:00                  12
#
#    fraud_risk_score preferred_category
# 0          0.090909           cultural
# 1          0.000000           cultural
# 2          0.000000             sports
# 3          0.000000             sports
# 4          0.166667             sports

# %%
# Build a training DataFrame with a simple binary label derived from fraud_risk_score.

train_df = build_fraud_training_dataframe(user_metrics, fraud_threshold=0.08)
train_df.head()
# Out:
#    lifetime_purchases  fraud_risk_score  is_fraud_label
# 0                  26          0.090909               1
# 1                  23          0.000000               0
# 2                  31          0.000000               0
# 3                  36          0.000000               0
# 4                  12          0.166667               1

# %%
# Optionally override the tracking URI here, or rely on ENV/`.env` via common.config.

# mlflow.set_tracking_uri("http://localhost:5000")

result = train_fraud_model(
    df=train_df,
    target_column="is_fraud_label",
    n_trials=5,
    test_size=0.2,
    random_state=123,
)

print("ROC AUC:", result.roc_auc)
print("Accuracy:", result.accuracy)
print("Run ID:", result.run_id)
print("Features:", result.feature_names)
# Out:
# [I 2026-02-07 13:27:54,277] A new study created in memory with name: no-name-2273be40-3f5d-4d23-b530-4e601085ebc4
# [I 2026-02-07 13:27:54,661] Trial 0 finished with value: 1.0 and parameters: {'max_depth': 3, 'learning_rate': 0.2833411258182807, 'n_estimators': 55, 'subsample': 0.6187738882833618, 'colsample_bytree': 0.9233559379303666}. Best is trial 0 with value: 1.0.
# [I 2026-02-07 13:27:54,888] Trial 1 finished with value: 1.0 and parameters: {'max_depth': 2, 'learning_rate': 0.06978080861468046, 'n_estimators': 32, 'subsample': 0.7092967129630142, 'colsample_bytree': 0.6588911366773879}. Best is trial 0 with value: 1.0.
# [I 2026-02-07 13:27:55,064] Trial 2 finished with value: 1.0 and parameters: {'max_depth': 3, 'learning_rate': 0.19118067723207482, 'n_estimators': 42, 'subsample': 0.9330462684750055, 'colsample_bytree': 0.7467531789964572}. Best is trial 0 with value: 1.0.
# [I 2026-02-07 13:27:55,203] Trial 3 finished with value: 1.0 and parameters: {'max_depth': 2, 'learning_rate': 0.15742710060610526, 'n_estimators': 51, 'subsample': 0.9500807050848434, 'colsample_bytree': 0.6269056570846597}. Best is trial 0 with value: 1.0.
# [I 2026-02-07 13:27:55,362] Trial 4 finished with value: 1.0 and parameters: {'max_depth': 4, 'learning_rate': 0.05102463546811039, 'n_estimators': 33, 'subsample': 0.8186816973727482, 'colsample_bytree': 0.6198641852354994}. Best is trial 0 with value: 1.0.
# [13:27:55] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0b3782d1791676daf-1\xgboost\xgboost-ci-windows\src\c_api\c_api.cc:1240: Saving into deprecated binary model format, please consider using `json` or `ubj`. Model format will default to JSON in XGBoost 2.2 if not specified.
# [13:27:56] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0b3782d1791676daf-1\xgboost\xgboost-ci-windows\src\c_api\c_api.cc:1240: Saving into deprecated binary model format, please consider using `json` or `ubj`. Model format will default to JSON in XGBoost 2.2 if not specified.
# ROC AUC: 1.0
# Accuracy: 1.0
# Run ID: 95164857968e47a19667696e8915f046
# Features: ['lifetime_purchases', 'fraud_risk_score']

# %% [markdown]
# You can now open the MLflow UI (default: `http://localhost:5000`) to inspect the
# runs, parameters, metrics, model artifact, and SHAP outputs under the
# `fraud_detection` experiment.
